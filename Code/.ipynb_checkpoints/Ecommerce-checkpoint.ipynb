# %%
import os
import pandas as pd

# Turn off warnings
import warnings
warnings.filterwarnings('ignore')
# File list 
file_directories = []

# List and save every file name in the input directory
for file in os.listdir('../Data'):
    print('../Data/', file, sep='/')
    file_directories.append(file)
# Out:
# ../Data//us-shein-appliances-3987.csv
# ../Data//us-shein-automotive-4110.csv
# ../Data//us-shein-baby_and_maternity-4433.csv
# ../Data//us-shein-bags_and_luggage-4299.csv
# ../Data//us-shein-beauty_and_health-4267.csv
# ../Data//us-shein-curve-2849.csv
# ../Data//us-shein-electronics-4395.csv
# ../Data//us-shein-home_and_kitchen-3719.csv
# ../Data//us-shein-home_textile-3883.csv
# ../Data//us-shein-jewelry_and_accessories-3548.csv
# ../Data//us-shein-kids-4314.csv
# ../Data//us-shein-mens_clothes-1891.csv
# ../Data//us-shein-office_and_school_supplies-4233.csv
# ../Data//us-shein-pet_supplies-4083.csv
# ../Data//us-shein-shoes-4381.csv
# ../Data//us-shein-sports_and_outdoors-3853.csv
# ../Data//us-shein-swimwear-3761.csv
# ../Data//us-shein-tools_and_home_improvement-3903.csv
# ../Data//us-shein-toys_and_games-3577.csv
# ../Data//us-shein-underwear_and_sleepwear-4019.csv
# ../Data//us-shein-womens_clothing-4620.csv

# %%
# Path where files are stored
data_folder = "../Data/"
prefix = "us-shein-"

# Create a list of DataFrame names
dfs = {}
df_names = []

# Iterate through each file and category name
for file in os.listdir(data_folder):
    if file.startswith(prefix) and file.endswith(".csv"):
        category = file.replace(prefix, "").replace(".csv", "")
        file_path = os.path.join(data_folder, file)

        dfs[category] = pd.read_csv(file_path)
        df_names.append(category)

df_names
# Out:
# ['appliances-3987',
#  'automotive-4110',
#  'baby_and_maternity-4433',
#  'bags_and_luggage-4299',
#  'beauty_and_health-4267',
#  'curve-2849',
#  'electronics-4395',
#  'home_and_kitchen-3719',
#  'home_textile-3883',
#  'jewelry_and_accessories-3548',
#  'kids-4314',
#  'mens_clothes-1891',
#  'office_and_school_supplies-4233',
#  'pet_supplies-4083',
#  'shoes-4381',
#  'sports_and_outdoors-3853',
#  'swimwear-3761',
#  'tools_and_home_improvement-3903',
#  'toys_and_games-3577',
#  'underwear_and_sleepwear-4019',
#  'womens_clothing-4620']

# %%
# Initialize counter
count = 0

# Clean each DataFrame and print progress
for count, (category, df) in enumerate(dfs.items(), start=1):
    dfs[category] = clean_data(df)
    print(count, f"- No Warnings in {category}")
# Out:
# 1 - No Warnings in appliances-3987
# 2 - No Warnings in automotive-4110
# 3 - No Warnings in baby_and_maternity-4433
# 4 - No Warnings in bags_and_luggage-4299
# 5 - No Warnings in beauty_and_health-4267
# 6 - No Warnings in curve-2849
# 7 - No Warnings in electronics-4395
# 8 - No Warnings in home_and_kitchen-3719
# 9 - No Warnings in home_textile-3883
# 10 - No Warnings in jewelry_and_accessories-3548
# 11 - No Warnings in kids-4314
# 12 - No Warnings in mens_clothes-1891
# 13 - No Warnings in office_and_school_supplies-4233
# 14 - No Warnings in pet_supplies-4083
# 15 - No Warnings in shoes-4381
# 16 - No Warnings in sports_and_outdoors-3853
# 17 - No Warnings in swimwear-3761
# 18 - No Warnings in tools_and_home_improvement-3903
# 19 - No Warnings in toys_and_games-3577
# 20 - No Warnings in underwear_and_sleepwear-4019
# 21 - No Warnings in womens_clothing-4620

# %%
def clean_data(df):
    '''
    This function takes in a category table of products and cleans it.
    
    Args: 
        df: DataFrame containing product data for a category.
    
    Returns: 
        df: A cleaned DataFrame.
    '''
    col_names = {}
    
    # Handle missing goods title column
    if ('goods-title-link' in df.columns) and ('goods-title-link--jump' in df.columns):
        # Merge the --jump goods titles and rename
        df.loc[:, 'goods-title-link'] = df['goods-title-link'].fillna(df['goods-title-link--jump'])

        # Drop unnecessary columns
        df = df.drop(columns=['goods-title-link--jump', 
                          'goods-title-link--jump href'])

    # Fill Discount NaNs and remove '%'
    df.loc[:, 'discount'] = df['discount'].fillna(0)
       # Handle missing selling proposition column
    if 'selling_proposition' in df.columns:
        df.loc[:, 'selling_proposition'] = df['selling_proposition'].str.replace('+ sold recently', '')
        col_names['selling_proposition'] =  'qty_sold'
        
    # Handle missing rank subcategory column
    if 'rank-sub' in df.columns:    
        df.loc[:, 'rank-sub'] = df['rank-sub'].str.replace('in', '')
        col_names['rank-sub'] =  'rank_category'
    
    # Handle missing color count column
    if 'color-count' in df.columns:
        col_names['color-count'] = 'color_count'
    
    # Handle black friday sale column
    if 'blackfridaybelts-bg src' in df.columns:
        df = df.drop(columns='blackfridaybelts-bg src')
        df['blackfridaybelts-content'] = df['blackfridaybelts-content'].str.replace('Save $', '')
        col_names['blackfridaybelts-content'] =  'black_friday_off_usd'
    
    if 'product-locatelabels-img src' in df.columns:
        col_names['product-locatelabels-img src'] = 'img_source_url'
    # Replace unnecessary text in columns
    df.loc[:, 'discount'] = df['discount'].str.replace('%', '')
    df.loc[:, 'price'] = df['price'].str.replace('$', '')


    # Rename columns
    col_names.update({'rank-title': 'rank',
                 'price': 'price_usd', 
                 'discount': 'pct_discount', 
                 'goods-title-link': 'product_title'})
    df = df.rename(columns=col_names)

    # Handle missing quantity sold column
    if 'qty_sold' in df.columns:
        # Change the 'k' to thousands 
        for col_num, col in enumerate(df.qty_sold):
            if 'k' in str(col):
                num = col.replace('k', '')
                df.qty_sold.iloc[col_num] = int(float(num)*1000)
    
    # pct_discount to absolute value
    df['pct_discount'] = [abs(float(disc)) for disc in df['pct_discount']]
    
    return df

# %%
df_names
# Out:
# ['appliances-3987',
#  'automotive-4110',
#  'baby_and_maternity-4433',
#  'bags_and_luggage-4299',
#  'beauty_and_health-4267',
#  'curve-2849',
#  'electronics-4395',
#  'home_and_kitchen-3719',
#  'home_textile-3883',
#  'jewelry_and_accessories-3548',
#  'kids-4314',
#  'mens_clothes-1891',
#  'office_and_school_supplies-4233',
#  'pet_supplies-4083',
#  'shoes-4381',
#  'sports_and_outdoors-3853',
#  'swimwear-3761',
#  'tools_and_home_improvement-3903',
#  'toys_and_games-3577',
#  'underwear_and_sleepwear-4019',
#  'womens_clothing-4620']

# %%
all_unique_columns = set()

for df in dfs.values():
    all_unique_columns.update(df.columns)

all_unique_columns
# Out:
# {'black_friday_off_usd',
#  'color_count',
#  'img_source_url',
#  'pct_discount',
#  'price_usd',
#  'product_title',
#  'qty_sold',
#  'rank',
#  'rank_category'}

# %%
all_dfs = []

for category, df in dfs.items():
    all_dfs.append(add_category_name(df.copy(), category))

merged_df = pd.concat(all_dfs, join='outer', ignore_index=True)

print("Merged DataFrame shape:", merged_df.shape)
# Out:
# Merged DataFrame shape: (82105, 10)

# %%
# Clean the rank column
rank_num = merged_df[['rank']].assign(
    first_part = lambda x: x['rank'].str.split(' ').str.get(0)
)
merged_df['rank'] = rank_num['first_part']

# %%
merged_df.head()
# Out:
#    rank                           rank_category price_usd  pct_discount  \
# 0    #1                              Give Gifts      2.03          22.0
# 1    #4                Top rated  Portable Fans      6.48          20.0
# 2   NaN                                     NaN      1.80           NaN
# 3   NaN                                     NaN      0.88          72.0
# 4    #6                         Oral Irrigators     12.06          40.0
# 5   #10                Refrigerators & Freezers      2.70           NaN
# 6    #8              Other Household Appliances      3.50           NaN
# 7   NaN                                     NaN      4.90           NaN
# 8    #6                    Oral Care Appliances      4.28          41.0
# 9    #9                    Household Appliances      2.76           5.0
# 10   #1   Women Shave & Hair Removal Appliances      4.29          35.0
# 11  NaN                                     NaN      2.50           NaN
# 12  NaN                                     NaN      2.70           NaN
# 13   #6                     Vacuum Food Sealers      4.80           NaN
# 14  NaN                                     NaN      1.49          55.0
# 15   #8                 Juicer & Food Processor      3.07          63.0
# 16   #5                  Cleang Appliance Parts      1.86          28.0
# 17  NaN                                     NaN     24.10           NaN
# 18   #9                      Laundry Appliances      0.75          53.0
# 19  NaN                                     NaN     14.60           NaN
# 20   #2                      Laundry Appliances     11.25          11.0
# 21  NaN                                     NaN      2.15          50.0
# 22  NaN                                     NaN      0.74          47.0
# 23   #6                 Fruit & Vegetable Tools      8.94          28.0
# 24  NaN                                     NaN      8.55          29.0
# 25  NaN                                     NaN      4.70          13.0
# 26   #7                                Blenders      3.46          48.0
# 27  NaN                                     NaN     12.50           NaN
# 28  NaN                                     NaN      2.60           4.0
# 29  NaN                                     NaN      4.20          22.0
# 30   #8                     Kitchen Meat Grders      9.30           NaN
# 31   #6                             Egg Cookers      2.10           NaN
# 32  NaN                                     NaN      1.90           NaN
# 33  #10                           Air Purifiers      6.12          40.0
# 34  NaN                                     NaN      4.66          20.0
# 35  NaN                                     NaN      5.96          47.0
# 36  NaN                                     NaN      1.60           NaN
# 37  NaN                                     NaN     23.50           NaN
# 38  NaN                                     NaN      3.90          29.0
# 39  NaN                                     NaN      1.70           NaN
# 40  #10                  Other Body Care Maches      2.70           NaN
# 41   #1                             Hair Dryers      4.38          32.0
# 42   #2            Electric Nose & Ear Trimmers      2.86          25.0
# 43   #7                 Juicer & Food Processor      3.46          51.0
# 44   #7                  Cleang Appliance Parts      2.40           NaN
# 45   #8                   Electric Toothbrushes      2.60           NaN
# 46   #5            Electric Nose & Ear Trimmers      2.10          46.0
# 47  NaN                                     NaN     35.00           NaN
# 48   #9            Specialty Kitchen Appliances      4.40           NaN
# 49  NaN                                     NaN      2.95          16.0
#
#    qty_sold                                      product_title  \
# 0       NaN  1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1       NaN                      1pc Portable Hanging Neck Fan
# 2       400  1pc Pink Colored Curved Eyelash Curler False E...
# 3      5600  1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4       NaN  Wit Water Flosser,Portable Oral Irrigator With...
# 5       NaN  1pc Ice Pop Mold, Plastic Ice Cream Mold, Froz...
# 6       NaN  Mini Pocket Bluetooth Thermal Printer, Portabl...
# 7       NaN  1 PC 400ML Classic Ultra-Silent Air Humidifier...
# 8       NaN  6 Modes Multi-Functional Sonic Electric Toothb...
# 9       NaN  1pc AA Battery Operated Portable Handheld Mini...
# 10      NaN  Teckwe Epilator,2*AAA Batteries Portability Re...
# 11       50  1pc Portable Pink Electric Eyelash Curler, USB...
# 12       30  Reusable Magic Hair Eraser, Painless Exfoliato...
# 13      NaN  Vacuum Sealer For 110V-220V, Food Protector Va...
# 14       60  3pcs/Set Laundry Drying Balls, 6cm Reusable Ho...
# 15      NaN  1pc 900ml Manual Food Processor Garlic Vegetab...
# 16      NaN  1pc White Half-Wrap Fan Dustproof Cover For Ho...
# 17      NaN  Ear Wax Removal Tool Camera,Ear Cleaner With C...
# 18      NaN  1pc Blue Lint Remover, Wool Sweater Shaver, Cl...
# 19       30  1pc Four Layer Slide Egg Storage Box, Refriger...
# 20      NaN  New 2 In 1 Mini Irons, Mini Travel Iron, Porta...
# 21      100  Mini Portable USB Charging Sealing Machine For...
# 22      100                            1pc Plain Egg Separator
# 23      NaN  6 Blades USB Portable Juicer Maker, Juicer Fru...
# 24      200  1PC 16LED USB/Battery Dual Use Makeup Mirror L...
# 25      NaN  1pc Silicone Ice Cube Trays With Lids, 2 Inche...
# 26      NaN  1pc Pink 500ml Manual Garlic Masher For Home U...
# 27      100  1pc Wax Bean Heater Hair Removal Tool For Both...
# 28     8700  1PC Epilator Face Hair Removal Lipstick Shaver...
# 29      200  1pc + Rechargeable + 500mah Lithium Battery + ...
# 30      NaN  Electric Garlic Masher, Portable Mini Garlic C...
# 31      NaN  1pc 4-Grid Egg Frying Pan, Kitchen Baking Mold...
# 32      100  2-In-1 Watermelon Fork Slicer Cutter, 2024 Sum...
# 33      NaN  O3 Ozone Generator Air Purifier,Refrigerator D...
# 34      100  1pc 4D Multifunctional Lifting And Tightening ...
# 35       10  5 In 1 Multi-Function Electric Scrubber  Porta...
# 36     1600  1pc 10ml Oil-Based Aroma Refill, Suitable For ...
# 37      NaN  Electric Hair Straightener Brush Straightening...
# 38       30              1pc Silicone Ice Cube Trays With Lids
# 39      NaN  1pc Kitchen Long-Handled Noodle & Soup Straine...
# 40      NaN  4pcs Makeup Sponge Beauty Egg Set - Makeup Spo...
# 41      NaN  1pc Salon Tools Black Pink Universal Silicone ...
# 42      NaN  Portable Lithium Battery Powered Hair Trimmer ...
# 43      NaN  Multifunctional Manual Food Chopper, Kitchen V...
# 44      NaN  1 Set Of 2 Portable Fan Cleaning Brushes, Hous...
# 45      NaN  Smart Electric Toothbrush With 6 Modes 42000vp...
# 46      NaN  1pc 12.7cm Aluminum Metal Electric Battery Typ...
# 47      NaN  Professional Curler, Electrically Heated Autom...
# 48      NaN  1pc Mini Bag Sealer, Rechargeable Portable Sea...
# 49      100  New Mini Nail Lamp Portable Led Uv Lamp Usb Na...
#
#       category_name  color_count black_friday_off_usd img_source_url
# 0   appliances-3987          NaN                  NaN            NaN
# 1   appliances-3987          NaN                  NaN            NaN
# 2   appliances-3987          NaN                  NaN            NaN
# 3   appliances-3987          NaN                  NaN            NaN
# 4   appliances-3987          NaN                  NaN            NaN
# 5   appliances-3987          NaN                  NaN            NaN
# 6   appliances-3987          NaN                  NaN            NaN
# 7   appliances-3987          NaN                  NaN            NaN
# 8   appliances-3987          NaN                  NaN            NaN
# 9   appliances-3987          NaN                  NaN            NaN
# 10  appliances-3987          NaN                  NaN            NaN
# 11  appliances-3987          NaN                  NaN            NaN
# 12  appliances-3987          NaN                  NaN            NaN
# 13  appliances-3987          NaN                  NaN            NaN
# 14  appliances-3987          NaN                  NaN            NaN
# 15  appliances-3987          NaN                  NaN            NaN
# 16  appliances-3987          NaN                  NaN            NaN
# 17  appliances-3987          NaN                  NaN            NaN
# 18  appliances-3987          NaN                  NaN            NaN
# 19  appliances-3987          NaN                  NaN            NaN
# 20  appliances-3987          NaN                  NaN            NaN
# 21  appliances-3987          NaN                  NaN            NaN
# 22  appliances-3987          NaN                  NaN            NaN
# 23  appliances-3987          NaN                  NaN            NaN
# 24  appliances-3987          NaN                  NaN            NaN
# 25  appliances-3987          NaN                  NaN            NaN
# 26  appliances-3987          NaN                  NaN            NaN
# 27  appliances-3987          NaN                  NaN            NaN
# 28  appliances-3987          NaN                  NaN            NaN
# 29  appliances-3987          NaN                  NaN            NaN
# 30  appliances-3987          NaN                  NaN            NaN
# 31  appliances-3987          NaN                  NaN            NaN
# 32  appliances-3987          NaN                  NaN            NaN
# 33  appliances-3987          NaN                  NaN            NaN
# 34  appliances-3987          NaN                  NaN            NaN
# 35  appliances-3987          NaN                  NaN            NaN
# 36  appliances-3987          NaN                  NaN            NaN
# 37  appliances-3987          NaN                  NaN            NaN
# 38  appliances-3987          NaN                  NaN            NaN
# 39  appliances-3987          NaN                  NaN            NaN
# 40  appliances-3987          NaN                  NaN            NaN
# 41  appliances-3987          NaN                  NaN            NaN
# 42  appliances-3987          NaN                  NaN            NaN
# 43  appliances-3987          NaN                  NaN            NaN
# 44  appliances-3987          NaN                  NaN            NaN
# 45  appliances-3987          NaN                  NaN            NaN
# 46  appliances-3987          NaN                  NaN            NaN
# 47  appliances-3987          NaN                  NaN            NaN
# 48  appliances-3987          NaN                  NaN            NaN
# 49  appliances-3987          NaN                  NaN            NaN

# %%
merged_df
# Out:
#       rank              rank_category price_usd  pct_discount qty_sold  \
# 0       #1                 Give Gifts      2.03          22.0      NaN
# 1       #4   Top rated  Portable Fans      6.48          20.0      NaN
# 2      NaN                        NaN      1.80           NaN      400
# 3      NaN                        NaN      0.88          72.0     5600
# 4       #6            Oral Irrigators     12.06          40.0      NaN
# ...    ...                        ...       ...           ...      ...
# 82100   #2    In Modest World Apparel     35.69           NaN      NaN
# 82101  NaN                        NaN     42.49           NaN       10
# 82102  NaN                        NaN     49.29           NaN      200
# 82103  #10      In Sexy Women Bottoms      9.78           5.0      NaN
# 82104  NaN                        NaN     21.19           NaN      NaN
#
#                                            product_title  \
# 0      1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1                          1pc Portable Hanging Neck Fan
# 2      1pc Pink Colored Curved Eyelash Curler False E...
# 3      1 Mini Portable Handheld Fan With 2 Aa Batteri...
# 4      Wit Water Flosser,Portable Oral Irrigator With...
# ...                                                  ...
# 82100  Colorful Flower Embroidered Linen Muslim Women...
# 82101  Elegant And Stylish Patchwork Lace Cheongsam D...
# 82102                  Split Thigh Satin Tube Prom Dress
# 82103  DAZY Women's Solid Color Low Waist Ultra Short...
# 82104  SHEIN Najma Women's Elegant Solid Color Batwin...
#
#               category_name  color_count black_friday_off_usd  \
# 0           appliances-3987          NaN                  NaN
# 1           appliances-3987          NaN                  NaN
# 2           appliances-3987          NaN                  NaN
# 3           appliances-3987          NaN                  NaN
# 4           appliances-3987          NaN                  NaN
# ...                     ...          ...                  ...
# 82100  womens_clothing-4620          NaN                  NaN
# 82101  womens_clothing-4620          NaN                  NaN
# 82102  womens_clothing-4620          5.0                  NaN
# 82103  womens_clothing-4620          6.0                  NaN
# 82104  womens_clothing-4620          NaN                  NaN
#
#                                           img_source_url
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 82100                                                NaN
# 82101                                                NaN
# 82102                                                NaN
# 82103                                                NaN
# 82104  https://img.ltwebstatic.com/images3_pi/2022/11...
#
# [82105 rows x 10 columns]
